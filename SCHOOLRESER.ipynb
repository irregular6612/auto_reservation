# %%
import requests 
from datetime import datetime 
import json

lrnPd =1
datedata = str(datetime.now())
datecode = datedata[0:4] + datedata[5:7] + datedata[8:10] #.으로 구분되어 있어서 슬라이싱 해줌


url_login ='http://academic.petapop.com/sign/actionLogin.do' #로그인 창 정보
url_att = 'http://academic.petapop.com/self/writeSelfLrnReqst.do?searchSgnId='+str(datecode) #전체 시간표 선택
url_send = 'http://academic.petapop.com/self/requestSelfLrn.do?sgnId='+str(datecode)+'&lrnPd='+str(lrnPd) #정보를 보낸다
url_del = 'http://academic.petapop.com/self/deleteSelfLrn.do'
user = {
     'id':'jacop0125',
     'password':'12345678'
  }

EBS = {
     'clssrmId' : 'CLSSRM_0000000000025',
     'roomTcherId' : 'USRCNFRM_00000000174', #담임 선생님 아이디
     'cchTcherId' : 'USRCNFRM_00000000346' #교사 신청
  } 
  
InD = {
      'clssrmId' : 'CLSSRM_0000000000039',
      'roomTcherId' : 'USRCNFRM_00000000174' ,
      'cchTcherId' : 'USRCNFRM_00000000174'
  }
Hugae = {
      'clssrmId' : 'CLSSRM_0000000000005',
      'roomTcherId' : 'USRCNFRM_00000000174' ,
      'cchTcherId' : 'USRCNFRM_00000000174'
  }
Moohan = {
      'clssrmId' : 'CLSSRM_0000000000055',
      'roomTcherId' : 'USRCNFRM_00000000174' ,
      'cchTcherId' : 'USRCNFRM_00000000174'
  }
compu = {
      'clssrmId' : 'CLSSRM_0000000000010',
      'roomTcherId' : 'USRCNFRM_00000000174' ,
      'cchTcherId' : 'USRCNFRM_00000000013'
  }

class31 = {
    'clssrmId': 'CLSSRM_0000000000007',
    'oomTcherId': 'USRCNFRM_00000000174',
    'cchTcherId': 'USRCNFRM_00000000174'
}
  

with requests.Session() as sess:
  res = sess.post(url_login,data=user) # 로그인
  res2 = sess.get(url_att) #전체 시간표 선택 get으로도 정보 보낼 수 있음
  res3 = sess.post(url_send,data=EBS) #EBS 선택

real = str(res3.content.decode("utf8"))
start = real.find("{")
length= len(real)
real = real[::-1]
end = length - real.find("}") +1
print(start,end)
real = real[::-1]
data = json.loads(real[start:end])
slrnNo = data["slrnNo"]
print(slrnNo)
print(data["result"]["success"],"\n")
print("현재 좌석 수는",data["stdntCount"])
# Out:
# 0 1193
# 25860
# True
#
# 현재 좌석 수는 3

# %%
# 완성된 최종 버전 입니다.
import requests 
from datetime import datetime 
import json

def auto(k,classdata):
  lrnPd = k
  datedata = str(datetime.now())
  datecode = datedata[0:4] + datedata[5:7] + datedata[8:10] #.으로 구분되어 있어서 슬라이싱 해줌


  url_login ='http://academic.petapop.com/sign/actionLogin.do' #로그인 창 정보
  url_att = 'http://academic.petapop.com/self/writeSelfLrnReqst.do?searchSgnId='+str(datecode) #전체 시간표 선택
  url_send = 'http://academic.petapop.com/self/requestSelfLrn.do?sgnId='+str(datecode)+'&lrnPd='+str(lrnPd) #정보를 보낸다
  
  
  user = {
     'id':'jacop0125',
     'password':'12345678'
  }

  EBS = {
     'clssrmId' : 'CLSSRM_0000000000025',
     'roomTcherId' : 'USRCNFRM_00000000174', #담임 선생님 아이디
     'cchTcherId' : 'USRCNFRM_00000000346' #교사 신청
  } 
  
  InD = {
      'clssrmId' : 'CLSSRM_0000000000039',
      'roomTcherId' : 'USRCNFRM_00000000174' ,
      'cchTcherId' : 'USRCNFRM_00000000174'
  }
  Hugae = {
      'clssrmId' : 'CLSSRM_0000000000005',
      'roomTcherId' : 'USRCNFRM_00000000174' ,
      'cchTcherId' : 'USRCNFRM_00000000174'
  }
  Moohan = {
      'clssrmId' : 'CLSSRM_0000000000055',
      'roomTcherId' : 'USRCNFRM_00000000174' ,
      'cchTcherId' : 'USRCNFRM_00000000174'
  }
  compu = {
      'clssrmId' : 'CLSSRM_0000000000010',
      'roomTcherId' : 'USRCNFRM_00000000174' ,
      'cchTcherId' : 'USRCNFRM_00000000013'
  }

  with requests.Session() as sess:
    res = sess.post(url_login,data=user) # 로그인
    res2 = sess.get(url_att) #전체 시간표 선택 get으로도 정보 보낼 수 있음
    if classdata == 'EBS':
      res3 = sess.post(url_send,data=EBS) #EBS 선택
    elif classdata == 'InD':
      res3 = sess.post(url_send,data=InD) #EBS 선택
    elif classdata == 'Hugae':
      res3 = sess.post(url_send,data=Hugae) #EBS 선택
    elif classdata == 'Moohan':
      res3 = sess.post(url_send,data=Moohan) #EBS 선택
    elif classdata == 'compu':
      res3 = sess.post(url_send,data=compu) #EBS 선택

  real = str(res3.content.decode("utf8"))
  start = real.find("{")
  length= len(real)
  real = real[::-1]
  end = length - real.find("}") +1
  real = real[::-1]
  data = json.loads(real[start:end])
  slrnNo = data["slrnNo"]
  if data["result"]["success"] == 'True':
    print('자리 예약을 성공적으로 마무리 했습니다.')
  else:
    print("잔여 좌석이 부족합니다. 예약에 실패하셨습니다.")
  print("현재 좌석 수는",data["stdntCount"])


q1 = input("몇교시 야자를 사용하시겠습니까?")
state = 0

if  '1' in q1:
  while state == 0:
    q2 = input("어떤 특별실을 사용하시겠습니까?(EBS,InD, Hugae,Moohan,compu)")
    if q2 in 'EBS,InD, Hugae,Moohan,compu' : 
      state = 1
      auto(1,q2)
    else:
      print('정확히 다시 입력해주십시오.')
state = 0 

if  '2' in q1:
  while state == 0:
    q3 = input("어떤 특별실을 사용하시겠습니까?(EBS,InD, Hugae,Moohan,compu)")
    if q3 in 'EBS,InD, Hugae,Moohan,compu' : 
      state = 1
      auto(2,q3)
    else:
      print('정확히 다시 입력해주십시오.')
state = 0 

if '3' in q1:
  while state == 0:
    q4 = input("어떤 특별실을 사용하시겠습니까?(EBS,InD, Hugae,Moohan,compu)")
    if q4 in 'EBS,InD, Hugae,Moohan,compu' : 
      state = 1
      auto(3,q4)
    else:
      print('정확히 다시 입력해주십시오.')
state = 0
# Out:
# 몇교시 야자를 사용하시겠습니까?1 2 3
# 어떤 특별실을 사용하시겠습니까?(EBS,InD, Hugae,Moohan,compu)EBS
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-2-141dbc8ca89c> in <module>()
#      83     if q2 in 'EBS,InD, Hugae,Moohan,compu' :
#      84       state = 1
# ---> 85       auto(1,q2)
#      86     else:
#      87       print('정확히 다시 입력해주십시오.')
#
# <ipython-input-2-141dbc8ca89c> in auto(k, classdata)
#      67   real = real[::-1]
#      68   data = json.loads(real[start:end])
# ---> 69   slrnNo = data["slrnNo"]
#      70   if data["result"]["success"] == 'True':
#      71     print('자리 예약을 성공적으로 마무리 했습니다.')
#
# KeyError: 'slrnNo'

# %%
# 자동 대기중인 매크로 입니다.
import requests 
from datetime import datetime 
import json

def auto(k,classdata):
  lrnPd = k
  datedata = str(datetime.now())
  datecode = datedata[0:4] + datedata[5:7] + datedata[8:10] #.으로 구분되어 있어서 슬라이싱 해줌


  url_login ='http://academic.petapop.com/sign/actionLogin.do' #로그인 창 정보
  url_att = 'http://academic.petapop.com/self/writeSelfLrnReqst.do?searchSgnId='+str(datecode) #전체 시간표 선택
  url_send = 'http://academic.petapop.com/self/requestSelfLrn.do?sgnId='+str(datecode)+'&lrnPd='+str(lrnPd) #정보를 보낸다
  
  
  user = {
     'id':'jacop0125',
     'password':'12345678'
  }

  EBS = {
     'clssrmId' : 'CLSSRM_0000000000025',
     'roomTcherId' : 'USRCNFRM_00000000174', #담임 선생님 아이디
     'cchTcherId' : 'USRCNFRM_00000000346' #교사 신청
  } 
  
  InD = {
      'clssrmId' : 'CLSSRM_0000000000039',
      'roomTcherId' : 'USRCNFRM_00000000174' ,
      'cchTcherId' : 'USRCNFRM_00000000174'
  }
  Hugae = {
      'clssrmId' : 'CLSSRM_0000000000005',
      'roomTcherId' : 'USRCNFRM_00000000174' ,
      'cchTcherId' : 'USRCNFRM_00000000174'
  }
  Moohan = {
      'clssrmId' : 'CLSSRM_0000000000055',
      'roomTcherId' : 'USRCNFRM_00000000174' ,
      'cchTcherId' : 'USRCNFRM_00000000174'
  }
  compu = {
      'clssrmId' : 'CLSSRM_0000000000010',
      'roomTcherId' : 'USRCNFRM_00000000174' ,
      'cchTcherId' : 'USRCNFRM_00000000013'
  }

  with requests.Session() as sess:
    res = sess.post(url_login,data=user) # 로그인
    res2 = sess.get(url_att) #전체 시간표 선택 get으로도 정보 보낼 수 있음
    if classdata == 'EBS':
      res3 = sess.post(url_send,data=EBS) #EBS 선택
    elif classdata == 'InD':
      res3 = sess.post(url_send,data=InD) #EBS 선택
    elif classdata == 'Hugae':
      res3 = sess.post(url_send,data=Hugae) #EBS 선택
    elif classdata == 'Moohan':
      res3 = sess.post(url_send,data=Moohan) #EBS 선택
    elif classdata == 'compu':
      res3 = sess.post(url_send,data=compu) #EBS 선택

  real = str(res3.content.decode("utf8"))
  start = real.find("{")
  length= len(real)
  real = real[::-1]
  end = length - real.find("}") +1
  real = real[::-1]
  data = json.loads(real[start:end])
  slrnNo = data["slrnNo"]
  if data["result"]["success"] == 'True':
    print('자리 예약을 성공적으로 마무리 했습니다.')
  else:
    print("잔여 좌석이 부족합니다. 예약에 실패하셨습니다.")
  print("현재 좌석 수는",data["stdntCount"])


while True:
  if str(datetime.now())[11:19] == '23:10:20':
    #q1 = input("몇교시 야자를 사용하시겠습니까?")
    q1 = '1 2 3'    #자동매크로 수정
    state = 0

    if  '1' in q1:
      while state == 0:
        q2 = input("어떤 특별실을 사용하시겠습니까?(EBS,InD, Hugae,Moohan,compu)")
        if q2 in 'EBS,InD, Hugae,Moohan,compu' : 
          state = 1
          auto(1,'EBS')     #자동매크로 수정
        else:
          print('정확히 다시 입력해주십시오.')
    state = 0 

    if  '2' in q1:
      while state == 0:
        q3 = input("어떤 특별실을 사용하시겠습니까?(EBS,InD, Hugae,Moohan,compu)")
        if q3 in 'EBS,InD, Hugae,Moohan,compu' : 
          state = 1
          auto(2,'EBS')      #자동매크로 수정
        else:
          print('정확히 다시 입력해주십시오.')
    state = 0 

    if '3' in q1:
      while state == 0:
        q4 = input("어떤 특별실을 사용하시겠습니까?(EBS,InD, Hugae,Moohan,compu)")
        if q4 in 'EBS,InD, Hugae,Moohan,compu' : 
          state = 1
          auto(3,'EBS')     #자동매크로 수정
        else:
          print('정확히 다시 입력해주십시오.')
    state = 0 
    
  else:
    pass
# Out:
# 몇교시 야자를 사용하시겠습니까?1 2 3
# 어떤 특별실을 사용하시겠습니까?(EBS,InD, Hugae,Moohan,compu)EBS
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-1-b68a786646e4> in <module>()
#      86         if q2 in 'EBS,InD, Hugae,Moohan,compu' :
#      87           state = 1
# ---> 88           auto(1,'EBS')     #자동매크로 수정
#      89         else:
#      90           print('정확히 다시 입력해주십시오.')
#
# <ipython-input-1-b68a786646e4> in auto(k, classdata)
#      67   real = real[::-1]
#      68   data = json.loads(real[start:end])
# ---> 69   slrnNo = data["slrnNo"]
#      70   if data["result"]["success"] == 'True':
#      71     print('자리 예약을 성공적으로 마무리 했습니다.')
#
# KeyError: 'slrnNo'

# %%
import  requests
